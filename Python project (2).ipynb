# %% [markdown]
# SHOPPING CENTER DATA

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r"C:\Users\Dell\Downloads\unclean_shopping_center_data_1000x10.xlsx")
df
# Out:
#     Shop_ID     Shop_Name     Category Floor_No  Monthly_Sales Area_sqft  \
# 0      SHP1    FashionHub         Food        2        75000.0       200
# 1         2    FashionHub          NaN        3        75000.0     Large
# 2      SHP3      FoodZone     Clothing        2        -5000.0       800
# 3       NaN           NaN  Electronics   Ground            NaN       800
# 4      SHP5     DailyMart  Electronics        2        75000.0       200
# ..      ...           ...          ...      ...            ...       ...
# 995  SHP996     DailyMart         Food   Ground       200000.0       NaN
# 996     NaN     DailyMart          NaN        3        50000.0       350
# 997     998     DailyMart  Electronics        0      9999999.0       NaN
# 998     NaN  ElectroWorld      Grocery      NaN       200000.0       NaN
# 999     NaN     DailyMart      Grocery        0      9999999.0       800
#
#     Owner_Name  Opening_Year       Contact_Email Contact_Number
# 0       Owner#          1895                 NaN     9876543210
# 1       Owner#          1895  mallshop@yahoo.com          12345
# 2          NaN          2010            contact@            NaN
# 3     R. Mehta          2005                 NaN     9876543210
# 4     R. Mehta  Two Thousand            contact@            NaN
# ..         ...           ...                 ...            ...
# 995        NaN           NaN            contact@            NaN
# 996        NaN          1895            contact@     9876543210
# 997    S. Khan          2018            contact@          12345
# 998        NaN  Two Thousand                 NaN     98XY543210
# 999   R. Mehta          2010                 NaN          12345
#
# [1000 rows x 10 columns]

# %%
df.shape       #.shape function show how many rows and columns in data.
# Out:
# (1000, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Shop_ID         513 non-null    object
#  1   Shop_Name       742 non-null    object
#  2   Category        873 non-null    object
#  3   Floor_No        861 non-null    object
#  4   Monthly_Sales   845 non-null    float64
#  5   Area_sqft       848 non-null    object
#  6   Owner_Name      680 non-null    object
#  7   Opening_Year    827 non-null    object
#  8   Contact_Email   606 non-null    object
#  9   Contact_Number  619 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 78.3+ KB

# %%
df.isnull().sum() #.isnull() represented the null values in data.
# Out:
# Shop_ID           487
# Shop_Name         258
# Category          127
# Floor_No          139
# Monthly_Sales     155
# Area_sqft         152
# Owner_Name        320
# Opening_Year      173
# Contact_Email     394
# Contact_Number    381
# dtype: int64

# %%
df.head() #.head show the strating five rows data.
# Out:
#   Shop_ID   Shop_Name     Category Floor_No  Monthly_Sales Area_sqft  \
# 0    SHP1  FashionHub         Food        2        75000.0       200
# 1       2  FashionHub          NaN        3        75000.0     Large
# 2    SHP3    FoodZone     Clothing        2        -5000.0       800
# 3     NaN         NaN  Electronics   Ground            NaN       800
# 4    SHP5   DailyMart  Electronics        2        75000.0       200
#
#   Owner_Name  Opening_Year       Contact_Email Contact_Number
# 0     Owner#          1895                 NaN     9876543210
# 1     Owner#          1895  mallshop@yahoo.com          12345
# 2        NaN          2010            contact@            NaN
# 3   R. Mehta          2005                 NaN     9876543210
# 4   R. Mehta  Two Thousand            contact@            NaN

# %%
df.tail()
df
# Out:
#     Shop_ID     Shop_Name     Category Floor_No  Monthly_Sales Area_sqft  \
# 0      SHP1    FashionHub         Food        2        75000.0       200
# 1         2    FashionHub          NaN        3        75000.0     Large
# 2      SHP3      FoodZone     Clothing        2        -5000.0       800
# 3       NaN           NaN  Electronics   Ground            NaN       800
# 4      SHP5     DailyMart  Electronics        2        75000.0       200
# ..      ...           ...          ...      ...            ...       ...
# 995  SHP996     DailyMart         Food   Ground       200000.0       NaN
# 996     NaN     DailyMart          NaN        3        50000.0       350
# 997     998     DailyMart  Electronics        0      9999999.0       NaN
# 998     NaN  ElectroWorld      Grocery      NaN       200000.0       NaN
# 999     NaN     DailyMart      Grocery        0      9999999.0       800
#
#     Owner_Name  Opening_Year       Contact_Email Contact_Number
# 0       Owner#          1895                 NaN     9876543210
# 1       Owner#          1895  mallshop@yahoo.com          12345
# 2          NaN          2010            contact@            NaN
# 3     R. Mehta          2005                 NaN     9876543210
# 4     R. Mehta  Two Thousand            contact@            NaN
# ..         ...           ...                 ...            ...
# 995        NaN           NaN            contact@            NaN
# 996        NaN          1895            contact@     9876543210
# 997    S. Khan          2018            contact@          12345
# 998        NaN  Two Thousand                 NaN     98XY543210
# 999   R. Mehta          2010                 NaN          12345
#
# [1000 rows x 10 columns]

# %%
df.drop_duplicates()  # it is delete the duplicaes rows present in data.
# Out:
#     Shop_ID     Shop_Name     Category Floor_No  Monthly_Sales Area_sqft  \
# 0      SHP1    FashionHub         Food        2        75000.0       200
# 1         2    FashionHub          NaN        3        75000.0     Large
# 2      SHP3      FoodZone     Clothing        2        -5000.0       800
# 3       NaN           NaN  Electronics   Ground            NaN       800
# 4      SHP5     DailyMart  Electronics        2        75000.0       200
# ..      ...           ...          ...      ...            ...       ...
# 995  SHP996     DailyMart         Food   Ground       200000.0       NaN
# 996     NaN     DailyMart          NaN        3        50000.0       350
# 997     998     DailyMart  Electronics        0      9999999.0       NaN
# 998     NaN  ElectroWorld      Grocery      NaN       200000.0       NaN
# 999     NaN     DailyMart      Grocery        0      9999999.0       800
#
#     Owner_Name  Opening_Year       Contact_Email Contact_Number
# 0       Owner#          1895                 NaN     9876543210
# 1       Owner#          1895  mallshop@yahoo.com          12345
# 2          NaN          2010            contact@            NaN
# 3     R. Mehta          2005                 NaN     9876543210
# 4     R. Mehta  Two Thousand            contact@            NaN
# ..         ...           ...                 ...            ...
# 995        NaN           NaN            contact@            NaN
# 996        NaN          1895            contact@     9876543210
# 997    S. Khan          2018            contact@          12345
# 998        NaN  Two Thousand                 NaN     98XY543210
# 999   R. Mehta          2010                 NaN          12345
#
# [999 rows x 10 columns]

# %%
df_clean = df.dropna()
df
# Out:
#     Shop_ID     Shop_Name     Category Floor_No  Monthly_Sales Area_sqft  \
# 0      SHP1    FashionHub         Food        2        75000.0       200
# 1         2    FashionHub          NaN        3        75000.0     Large
# 2      SHP3      FoodZone     Clothing        2        -5000.0       800
# 3       NaN           NaN  Electronics   Ground            NaN       800
# 4      SHP5     DailyMart  Electronics        2        75000.0       200
# ..      ...           ...          ...      ...            ...       ...
# 995  SHP996     DailyMart         Food   Ground       200000.0       NaN
# 996     NaN     DailyMart          NaN        3        50000.0       350
# 997     998     DailyMart  Electronics        0      9999999.0       NaN
# 998     NaN  ElectroWorld      Grocery      NaN       200000.0       NaN
# 999     NaN     DailyMart      Grocery        0      9999999.0       800
#
#     Owner_Name  Opening_Year       Contact_Email Contact_Number
# 0       Owner#          1895                 NaN     9876543210
# 1       Owner#          1895  mallshop@yahoo.com          12345
# 2          NaN          2010            contact@            NaN
# 3     R. Mehta          2005                 NaN     9876543210
# 4     R. Mehta  Two Thousand            contact@            NaN
# ..         ...           ...                 ...            ...
# 995        NaN           NaN            contact@            NaN
# 996        NaN          1895            contact@     9876543210
# 997    S. Khan          2018            contact@          12345
# 998        NaN  Two Thousand                 NaN     98XY543210
# 999   R. Mehta          2010                 NaN          12345
#
# [1000 rows x 10 columns]

# %%
num_cols = df.select_dtypes(include=['number']).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].median())
df
# Out:
#     Shop_ID     Shop_Name     Category Floor_No  Monthly_Sales Area_sqft  \
# 0      SHP1    FashionHub         Food        2        75000.0       200
# 1         2    FashionHub          NaN        3        75000.0     Large
# 2      SHP3      FoodZone     Clothing        2        -5000.0       800
# 3       NaN           NaN  Electronics   Ground       120000.0       800
# 4      SHP5     DailyMart  Electronics        2        75000.0       200
# ..      ...           ...          ...      ...            ...       ...
# 995  SHP996     DailyMart         Food   Ground       200000.0       NaN
# 996     NaN     DailyMart          NaN        3        50000.0       350
# 997     998     DailyMart  Electronics        0      9999999.0       NaN
# 998     NaN  ElectroWorld      Grocery      NaN       200000.0       NaN
# 999     NaN     DailyMart      Grocery        0      9999999.0       800
#
#     Owner_Name  Opening_Year       Contact_Email Contact_Number
# 0       Owner#          1895                 NaN     9876543210
# 1       Owner#          1895  mallshop@yahoo.com          12345
# 2          NaN          2010            contact@            NaN
# 3     R. Mehta          2005                 NaN     9876543210
# 4     R. Mehta  Two Thousand            contact@            NaN
# ..         ...           ...                 ...            ...
# 995        NaN           NaN            contact@            NaN
# 996        NaN          1895            contact@     9876543210
# 997    S. Khan          2018            contact@          12345
# 998        NaN  Two Thousand                 NaN     98XY543210
# 999   R. Mehta          2010                 NaN          12345
#
# [1000 rows x 10 columns]

# %%
cat_cols = df.select_dtypes(include=['object']).columns

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df
# Out:
#     Shop_ID     Shop_Name     Category Floor_No  Monthly_Sales Area_sqft  \
# 0      SHP1    FashionHub         Food        2        75000.0       200
# 1         2    FashionHub     Clothing        3        75000.0     Large
# 2      SHP3      FoodZone     Clothing        2        -5000.0       800
# 3      SHP1  ElectroWorld  Electronics   Ground       120000.0       800
# 4      SHP5     DailyMart  Electronics        2        75000.0       200
# ..      ...           ...          ...      ...            ...       ...
# 995  SHP996     DailyMart         Food   Ground       200000.0       500
# 996    SHP1     DailyMart     Clothing        3        50000.0       350
# 997     998     DailyMart  Electronics        0      9999999.0       500
# 998    SHP1  ElectroWorld      Grocery        2       200000.0       500
# 999    SHP1     DailyMart      Grocery        0      9999999.0       800
#
#     Owner_Name  Opening_Year       Contact_Email Contact_Number
# 0       Owner#          1895            contact@     9876543210
# 1       Owner#          1895  mallshop@yahoo.com          12345
# 2     R. Mehta          2010            contact@     9876543210
# 3     R. Mehta          2005            contact@     9876543210
# 4     R. Mehta  Two Thousand            contact@     9876543210
# ..         ...           ...                 ...            ...
# 995   R. Mehta          1895            contact@     9876543210
# 996   R. Mehta          1895            contact@     9876543210
# 997    S. Khan          2018            contact@          12345
# 998   R. Mehta  Two Thousand            contact@     98XY543210
# 999   R. Mehta          2010            contact@          12345
#
# [1000 rows x 10 columns]

# %%
df['Opening_Year'] = pd.to_numeric(df['Opening_Year'], errors='coerce')
df['Opening_Year'] = df['Opening_Year'].fillna(df['Opening_Year'].median())

# %%
df
# Out:
#     Shop_ID     Shop_Name     Category Floor_No  Monthly_Sales Area_sqft  \
# 0      SHP1    FashionHub         Food        2        75000.0       200
# 1         2    FashionHub     Clothing        3        75000.0     Large
# 2      SHP3      FoodZone     Clothing        2        -5000.0       800
# 3      SHP1  ElectroWorld  Electronics   Ground       120000.0       800
# 4      SHP5     DailyMart  Electronics        2        75000.0       200
# ..      ...           ...          ...      ...            ...       ...
# 995  SHP996     DailyMart         Food   Ground       200000.0       500
# 996    SHP1     DailyMart     Clothing        3        50000.0       350
# 997     998     DailyMart  Electronics        0      9999999.0       500
# 998    SHP1  ElectroWorld      Grocery        2       200000.0       500
# 999    SHP1     DailyMart      Grocery        0      9999999.0       800
#
#     Owner_Name  Opening_Year       Contact_Email Contact_Number
# 0       Owner#        1895.0            contact@     9876543210
# 1       Owner#        1895.0  mallshop@yahoo.com          12345
# 2     R. Mehta        2010.0            contact@     9876543210
# 3     R. Mehta        2005.0            contact@     9876543210
# 4     R. Mehta        2005.0            contact@     9876543210
# ..         ...           ...                 ...            ...
# 995   R. Mehta        1895.0            contact@     9876543210
# 996   R. Mehta        1895.0            contact@     9876543210
# 997    S. Khan        2018.0            contact@          12345
# 998   R. Mehta        2005.0            contact@     98XY543210
# 999   R. Mehta        2010.0            contact@          12345
#
# [1000 rows x 10 columns]

# %%
df.describe()
# Out:
#        Monthly_Sales  Opening_Year
# count   1.000000e+03   1000.000000
# mean    1.532440e+06   1967.898000
# std     3.489290e+06     55.223865
# min    -5.000000e+03   1895.000000
# 25%     5.000000e+04   1895.000000
# 50%     1.200000e+05   2005.000000
# 75%     2.000000e+05   2010.000000
# max     9.999999e+06   2018.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data export in Empty excel sheet

# %%
with pd.ExcelWriter(r'C:\Users\Dell\Desktop\projectfile.xlsx', engine='xlsxwriter') as writer:
    df.to_excel(writer, sheet_name='Sheet1', index=False)

# %% [markdown]
# ### VISUALIZATION START USING THE MATPLOTLIB AND SEABORN LIBRARY

# %% [markdown]
# MATPLOTLIB VISUALIZATIONS

# %%
plt.figure(figsize=(8,5))    # 1) Histogram — Monthly Sales
plt.hist(df['Monthly_Sales'].dropna(), bins=20)
plt.title("Distribution of Monthly Sales")
plt.xlabel("Monthly Sales")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))     # 2) Boxplot-Monthly Sales (ti detect outliers)
plt.boxplot(df['Monthly_Sales'].dropna())
plt.title("Boxplot of Monthly Sales")
plt.ylabel("Monthly Sales")
plt.show()

# %%
avg_sales = df.groupby('Category')['Monthly_Sales'].mean() # 3) Bar Chart — Average Sales by Category

plt.figure(figsize=(8,5))
avg_sales.plot(kind='bar')
plt.title("Average Monthly Sales by Category")
plt.xlabel("Category")
plt.ylabel("Average Sales")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# SEABORN VISUALIZATION

# %%
plt.figure(figsize=(8,5))   # 4) Seaborn Histogram + KDE (Sales Distribution)
sns.histplot(df['Monthly_Sales'].dropna(), kde=True)
plt.title("Monthly Sales Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))  # 5) Seaborn Boxplot — Category vs Sales
sns.boxplot(x='Category', y='Monthly_Sales', data=df)
plt.xticks(rotation=45)
plt.title("Category vs Monthly Sales")
plt.show()

# %%
plt.figure(figsize=(8,5)) # 6) Seaborn Barplot — Floor vs Average Sales
sns.barplot(x='Floor_No', y='Monthly_Sales', data=df)
plt.title("Floor vs Monthly Sales")
plt.show()

# %%
plt.figure(figsize=(8,5)) # OPTIONAL: Heatmap of Missing Values
sns.heatmap(df.isnull(), cmap="viridis", cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# Insights
#
# Sales: Mostly low–moderate, a few very high values → outliers present.
# Negative sales (-5000): Invalid data found.
# Opening Year: Some unrealistic values (e.g., 1895).
# Missing values: Present in many columns; filled using median (numeric) and mode (categorical).
# Category vs Sales: Some categories perform better than others.
# Floor vs Sales: Ground/1st floor generally has higher sales.

# %% [markdown]
# Conclusion
#
#
# The dataset had missing values, outliers, and incorrect entries, which were cleaned
# before analysis.
# Visualizations showed uneven sales distribution and variation across categories
# and floors.
# After cleaning, the data is more reliable for decision-making and further analysis.
